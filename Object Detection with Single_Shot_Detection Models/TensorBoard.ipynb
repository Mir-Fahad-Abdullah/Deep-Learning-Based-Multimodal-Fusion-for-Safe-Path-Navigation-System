# %%
import tensorflow as tf

log_dir = "C:/Users/ACER/Desktop/test_tensorboard_log"
writer = tf.summary.create_file_writer(log_dir)

with writer.as_default():
    for step in range(100):
        tf.summary.scalar("loss", 100 / (step + 1), step=step)
        tf.summary.scalar("accuracy", step / 100.0, step=step)
    writer.flush()

# %%
import tensorflow as tf

log_dir = "C:/Users/ACER/Desktop/test_tensorboard_log"
writer = tf.summary.create_file_writer(log_dir)

with writer.as_default():
    for step in range(100):
        tf.summary.scalar("loss", 100 / (step + 1), step=step)
        tf.summary.scalar("accuracy", step / 100.0, step=step)
    writer.flush()

# %%
tensorboard --logdir=C:/Users/ACER/Desktop/test_tensorboard_log
# Out:
#   Cell In[3], line 1
#     tensorboard --logdir=C:/Users/ACER/Desktop/test_tensorboard_log
#     ^
# SyntaxError: cannot assign to operator
