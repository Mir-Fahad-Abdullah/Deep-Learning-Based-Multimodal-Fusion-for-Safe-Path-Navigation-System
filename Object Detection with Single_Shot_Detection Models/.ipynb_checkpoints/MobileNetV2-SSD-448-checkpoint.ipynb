# %% [markdown]
# # Importing Libraries

# %%
import os
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from object_detection.utils import config_util
from object_detection.builders import model_builder
from object_detection import model_lib_v2
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras import mixed_precision
# Out:
# C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# # Directory Paths

# %%
REPO_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/models/research"
PIPELINE_CONFIG = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/pretrained/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config"
MODEL_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_448_model"
EVAL_DIR = os.path.join(MODEL_DIR, 'eval_logs')
os.makedirs(EVAL_DIR, exist_ok=True)

# %% [markdown]
# # Environment Setup

# %%
sys.path.append(os.path.join(REPO_DIR, 'slim'))
sys.path.append(os.path.join(REPO_DIR, 'object_detection'))
os.environ['PYTHONPATH'] = os.pathsep.join([os.environ.get('PYTHONPATH', ''), REPO_DIR, os.path.join(REPO_DIR, 'slim')])

# Enable memory growth
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# Mixed precision
mixed_precision.set_global_policy('float32')

# %% [markdown]
# # Training MobileNetv2-SSD Model

# %% [markdown]
# ### Training Loop

# %%
print("Starting training...")

model_lib_v2.train_loop(
    pipeline_config_path=PIPELINE_CONFIG,
    model_dir=MODEL_DIR,
    checkpoint_every_n=1000,
    record_summaries=True,
    num_steps_per_iteration=1
)
# Out:
# Starting training...
# INFO:tensorflow:Maybe overwriting train_steps: None
# [07/22 20:53:30] tensorflow INFO: Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# [07/22 20:53:30] tensorflow INFO: Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# [07/22 20:53:30] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/train.record']
# [07/22 20:53:30] tensorflow INFO: Reading unweighted datasets: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/train.record']
# [07/22 20:53:30] tensorflow INFO: Reading record datasets for input file: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# [07/22 20:53:30] tensorflow INFO: Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# [07/22 20:53:30] tensorflow WARNING: num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# [07/22 20:53:30] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# [07/22 20:53:30] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# [07/22 20:53:49] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# [07/22 20:53:58] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# [07/22 20:54:02] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Step 100 per-step time 0.442s
# [07/22 20:56:53] tensorflow INFO: Step 100 per-step time 0.442s
# INFO:tensorflow:{'Loss/classification_loss': 0.5520482,
#  'Loss/localization_loss': 0.36978176,
#  'Loss/regularization_loss': 0.15145475,
#  'Loss/total_loss': 1.0732846,
#  'learning_rate': 0.0319994}
# [07/22 20:56:53] tensorflow INFO: {'Loss/classification_loss': 0.5520482,
#  'Loss/localization_loss': 0.36978176,
#  'Loss/regularization_loss': 0.15145475,
#  'Loss/total_loss': 1.0732846,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.583s
# [07/22 20:57:43] tensorflow INFO: Step 200 per-step time 0.583s
# INFO:tensorflow:{'Loss/classification_loss': 0.43536013,
#  'Loss/localization_loss': 0.3725883,
#  'Loss/regularization_loss': 0.15156846,
#  'Loss/total_loss': 0.95951694,
#  'learning_rate': 0.0373328}
# [07/22 20:57:43] tensorflow INFO: {'Loss/classification_loss': 0.43536013,
#  'Loss/localization_loss': 0.3725883,
#  'Loss/regularization_loss': 0.15156846,
#  'Loss/total_loss': 0.95951694,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.447s
# [07/22 20:58:30] tensorflow INFO: Step 300 per-step time 0.447s
# INFO:tensorflow:{'Loss/classification_loss': 0.52472395,
#  'Loss/localization_loss': 0.30179876,
#  'Loss/regularization_loss': 0.1517655,
#  'Loss/total_loss': 0.9782882,
#  'learning_rate': 0.0426662}
# [07/22 20:58:30] tensorflow INFO: {'Loss/classification_loss': 0.52472395,
#  'Loss/localization_loss': 0.30179876,
#  'Loss/regularization_loss': 0.1517655,
#  'Loss/total_loss': 0.9782882,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.468s
# [07/22 20:59:18] tensorflow INFO: Step 400 per-step time 0.468s
# INFO:tensorflow:{'Loss/classification_loss': 0.35454264,
#  'Loss/localization_loss': 0.24538022,
#  'Loss/regularization_loss': 0.15207767,
#  'Loss/total_loss': 0.7520006,
#  'learning_rate': 0.047999598}
# [07/22 20:59:18] tensorflow INFO: {'Loss/classification_loss': 0.35454264,
#  'Loss/localization_loss': 0.24538022,
#  'Loss/regularization_loss': 0.15207767,
#  'Loss/total_loss': 0.7520006,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.538s
# [07/22 21:00:05] tensorflow INFO: Step 500 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.24487807,
#  'Loss/localization_loss': 0.15228678,
#  'Loss/regularization_loss': 0.15244871,
#  'Loss/total_loss': 0.5496136,
#  'learning_rate': 0.053333}
# [07/22 21:00:05] tensorflow INFO: {'Loss/classification_loss': 0.24487807,
#  'Loss/localization_loss': 0.15228678,
#  'Loss/regularization_loss': 0.15244871,
#  'Loss/total_loss': 0.5496136,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.467s
# [07/22 21:00:52] tensorflow INFO: Step 600 per-step time 0.467s
# INFO:tensorflow:{'Loss/classification_loss': 0.3401335,
#  'Loss/localization_loss': 0.35186517,
#  'Loss/regularization_loss': 0.15285653,
#  'Loss/total_loss': 0.8448552,
#  'learning_rate': 0.0586664}
# [07/22 21:00:52] tensorflow INFO: {'Loss/classification_loss': 0.3401335,
#  'Loss/localization_loss': 0.35186517,
#  'Loss/regularization_loss': 0.15285653,
#  'Loss/total_loss': 0.8448552,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.443s
# [07/22 21:01:41] tensorflow INFO: Step 700 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.3855614,
#  'Loss/localization_loss': 0.28237206,
#  'Loss/regularization_loss': 0.15340815,
#  'Loss/total_loss': 0.82134163,
#  'learning_rate': 0.0639998}
# [07/22 21:01:41] tensorflow INFO: {'Loss/classification_loss': 0.3855614,
#  'Loss/localization_loss': 0.28237206,
#  'Loss/regularization_loss': 0.15340815,
#  'Loss/total_loss': 0.82134163,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.612s
# [07/22 21:02:29] tensorflow INFO: Step 800 per-step time 0.612s
# INFO:tensorflow:{'Loss/classification_loss': 0.27087048,
#  'Loss/localization_loss': 0.23082145,
#  'Loss/regularization_loss': 0.15397516,
#  'Loss/total_loss': 0.65566707,
#  'learning_rate': 0.069333196}
# [07/22 21:02:29] tensorflow INFO: {'Loss/classification_loss': 0.27087048,
#  'Loss/localization_loss': 0.23082145,
#  'Loss/regularization_loss': 0.15397516,
#  'Loss/total_loss': 0.65566707,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.442s
# [07/22 21:03:17] tensorflow INFO: Step 900 per-step time 0.442s
# INFO:tensorflow:{'Loss/classification_loss': 0.23540868,
#  'Loss/localization_loss': 0.19995193,
#  'Loss/regularization_loss': 0.15450463,
#  'Loss/total_loss': 0.5898652,
#  'learning_rate': 0.074666604}
# [07/22 21:03:17] tensorflow INFO: {'Loss/classification_loss': 0.23540868,
#  'Loss/localization_loss': 0.19995193,
#  'Loss/regularization_loss': 0.15450463,
#  'Loss/total_loss': 0.5898652,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.461s
# [07/22 21:04:06] tensorflow INFO: Step 1000 per-step time 0.461s
# INFO:tensorflow:{'Loss/classification_loss': 0.26966015,
#  'Loss/localization_loss': 0.17464788,
#  'Loss/regularization_loss': 0.1551976,
#  'Loss/total_loss': 0.59950566,
#  'learning_rate': 0.08}
# [07/22 21:04:06] tensorflow INFO: {'Loss/classification_loss': 0.26966015,
#  'Loss/localization_loss': 0.17464788,
#  'Loss/regularization_loss': 0.1551976,
#  'Loss/total_loss': 0.59950566,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.418s
# [07/22 21:04:55] tensorflow INFO: Step 1100 per-step time 0.418s
# INFO:tensorflow:{'Loss/classification_loss': 0.28007737,
#  'Loss/localization_loss': 0.19106276,
#  'Loss/regularization_loss': 0.15587264,
#  'Loss/total_loss': 0.6270128,
#  'learning_rate': 0.07999657}
# [07/22 21:04:55] tensorflow INFO: {'Loss/classification_loss': 0.28007737,
#  'Loss/localization_loss': 0.19106276,
#  'Loss/regularization_loss': 0.15587264,
#  'Loss/total_loss': 0.6270128,
#  'learning_rate': 0.07999657}
# INFO:tensorflow:Step 1200 per-step time 0.490s
# [07/22 21:05:41] tensorflow INFO: Step 1200 per-step time 0.490s
# INFO:tensorflow:{'Loss/classification_loss': 0.20307967,
#  'Loss/localization_loss': 0.1388544,
#  'Loss/regularization_loss': 0.15635441,
#  'Loss/total_loss': 0.4982885,
#  'learning_rate': 0.0799863}
# [07/22 21:05:41] tensorflow INFO: {'Loss/classification_loss': 0.20307967,
#  'Loss/localization_loss': 0.1388544,
#  'Loss/regularization_loss': 0.15635441,
#  'Loss/total_loss': 0.4982885,
#  'learning_rate': 0.0799863}
# INFO:tensorflow:Step 1300 per-step time 0.435s
# [07/22 21:06:28] tensorflow INFO: Step 1300 per-step time 0.435s
# INFO:tensorflow:{'Loss/classification_loss': 0.22638014,
#  'Loss/localization_loss': 0.12250256,
#  'Loss/regularization_loss': 0.15663634,
#  'Loss/total_loss': 0.50551903,
#  'learning_rate': 0.07996915}
# [07/22 21:06:28] tensorflow INFO: {'Loss/classification_loss': 0.22638014,
#  'Loss/localization_loss': 0.12250256,
#  'Loss/regularization_loss': 0.15663634,
#  'Loss/total_loss': 0.50551903,
#  'learning_rate': 0.07996915}
# INFO:tensorflow:Step 1400 per-step time 0.497s
# [07/22 21:07:15] tensorflow INFO: Step 1400 per-step time 0.497s
# INFO:tensorflow:{'Loss/classification_loss': 0.20344526,
#  'Loss/localization_loss': 0.13755724,
#  'Loss/regularization_loss': 0.15686864,
#  'Loss/total_loss': 0.49787113,
#  'learning_rate': 0.079945184}
# [07/22 21:07:15] tensorflow INFO: {'Loss/classification_loss': 0.20344526,
#  'Loss/localization_loss': 0.13755724,
#  'Loss/regularization_loss': 0.15686864,
#  'Loss/total_loss': 0.49787113,
#  'learning_rate': 0.079945184}
# INFO:tensorflow:Step 1500 per-step time 0.486s
# [07/22 21:08:03] tensorflow INFO: Step 1500 per-step time 0.486s
# INFO:tensorflow:{'Loss/classification_loss': 0.18493599,
#  'Loss/localization_loss': 0.08992049,
#  'Loss/regularization_loss': 0.15688129,
#  'Loss/total_loss': 0.43173778,
#  'learning_rate': 0.07991436}
# [07/22 21:08:03] tensorflow INFO: {'Loss/classification_loss': 0.18493599,
#  'Loss/localization_loss': 0.08992049,
#  'Loss/regularization_loss': 0.15688129,
#  'Loss/total_loss': 0.43173778,
#  'learning_rate': 0.07991436}
# INFO:tensorflow:Step 1600 per-step time 0.522s
# [07/22 21:08:51] tensorflow INFO: Step 1600 per-step time 0.522s
# INFO:tensorflow:{'Loss/classification_loss': 0.2132766,
#  'Loss/localization_loss': 0.13835786,
#  'Loss/regularization_loss': 0.15695636,
#  'Loss/total_loss': 0.5085908,
#  'learning_rate': 0.07987669}
# [07/22 21:08:51] tensorflow INFO: {'Loss/classification_loss': 0.2132766,
#  'Loss/localization_loss': 0.13835786,
#  'Loss/regularization_loss': 0.15695636,
#  'Loss/total_loss': 0.5085908,
#  'learning_rate': 0.07987669}
# INFO:tensorflow:Step 1700 per-step time 0.487s
# [07/22 21:09:39] tensorflow INFO: Step 1700 per-step time 0.487s
# INFO:tensorflow:{'Loss/classification_loss': 0.16148911,
#  'Loss/localization_loss': 0.09385998,
#  'Loss/regularization_loss': 0.15697156,
#  'Loss/total_loss': 0.41232067,
#  'learning_rate': 0.079832196}
# [07/22 21:09:39] tensorflow INFO: {'Loss/classification_loss': 0.16148911,
#  'Loss/localization_loss': 0.09385998,
#  'Loss/regularization_loss': 0.15697156,
#  'Loss/total_loss': 0.41232067,
#  'learning_rate': 0.079832196}
# INFO:tensorflow:Step 1800 per-step time 0.462s
# [07/22 21:10:26] tensorflow INFO: Step 1800 per-step time 0.462s
# INFO:tensorflow:{'Loss/classification_loss': 0.22652178,
#  'Loss/localization_loss': 0.09286518,
#  'Loss/regularization_loss': 0.15689765,
#  'Loss/total_loss': 0.47628462,
#  'learning_rate': 0.07978087}
# [07/22 21:10:26] tensorflow INFO: {'Loss/classification_loss': 0.22652178,
#  'Loss/localization_loss': 0.09286518,
#  'Loss/regularization_loss': 0.15689765,
#  'Loss/total_loss': 0.47628462,
#  'learning_rate': 0.07978087}
# INFO:tensorflow:Step 1900 per-step time 0.427s
# [07/22 21:11:14] tensorflow INFO: Step 1900 per-step time 0.427s
# INFO:tensorflow:{'Loss/classification_loss': 0.20881695,
#  'Loss/localization_loss': 0.1254086,
#  'Loss/regularization_loss': 0.1568145,
#  'Loss/total_loss': 0.49104005,
#  'learning_rate': 0.07972274}
# [07/22 21:11:14] tensorflow INFO: {'Loss/classification_loss': 0.20881695,
#  'Loss/localization_loss': 0.1254086,
#  'Loss/regularization_loss': 0.1568145,
#  'Loss/total_loss': 0.49104005,
#  'learning_rate': 0.07972274}
# INFO:tensorflow:Step 2000 per-step time 0.492s
# [07/22 21:12:01] tensorflow INFO: Step 2000 per-step time 0.492s
# INFO:tensorflow:{'Loss/classification_loss': 0.18224166,
#  'Loss/localization_loss': 0.12229105,
#  'Loss/regularization_loss': 0.1567119,
#  'Loss/total_loss': 0.4612446,
#  'learning_rate': 0.07965779}
# [07/22 21:12:01] tensorflow INFO: {'Loss/classification_loss': 0.18224166,
#  'Loss/localization_loss': 0.12229105,
#  'Loss/regularization_loss': 0.1567119,
#  'Loss/total_loss': 0.4612446,
#  'learning_rate': 0.07965779}
# INFO:tensorflow:Step 2100 per-step time 0.406s
# [07/22 21:12:51] tensorflow INFO: Step 2100 per-step time 0.406s
# INFO:tensorflow:{'Loss/classification_loss': 0.21788827,
#  'Loss/localization_loss': 0.095947005,
#  'Loss/regularization_loss': 0.15666078,
#  'Loss/total_loss': 0.47049606,
#  'learning_rate': 0.07958606}
# [07/22 21:12:51] tensorflow INFO: {'Loss/classification_loss': 0.21788827,
#  'Loss/localization_loss': 0.095947005,
#  'Loss/regularization_loss': 0.15666078,
#  'Loss/total_loss': 0.47049606,
#  'learning_rate': 0.07958606}
# INFO:tensorflow:Step 2200 per-step time 0.417s
# [07/22 21:13:37] tensorflow INFO: Step 2200 per-step time 0.417s
# INFO:tensorflow:{'Loss/classification_loss': 0.121912226,
#  'Loss/localization_loss': 0.074732475,
#  'Loss/regularization_loss': 0.15657209,
#  'Loss/total_loss': 0.35321677,
#  'learning_rate': 0.07950753}
# [07/22 21:13:37] tensorflow INFO: {'Loss/classification_loss': 0.121912226,
#  'Loss/localization_loss': 0.074732475,
#  'Loss/regularization_loss': 0.15657209,
#  'Loss/total_loss': 0.35321677,
#  'learning_rate': 0.07950753}
# INFO:tensorflow:Step 2300 per-step time 0.386s
# [07/22 21:14:24] tensorflow INFO: Step 2300 per-step time 0.386s
# INFO:tensorflow:{'Loss/classification_loss': 0.1912674,
#  'Loss/localization_loss': 0.070962444,
#  'Loss/regularization_loss': 0.15631768,
#  'Loss/total_loss': 0.41854754,
#  'learning_rate': 0.07942224}
# [07/22 21:14:24] tensorflow INFO: {'Loss/classification_loss': 0.1912674,
#  'Loss/localization_loss': 0.070962444,
#  'Loss/regularization_loss': 0.15631768,
#  'Loss/total_loss': 0.41854754,
#  'learning_rate': 0.07942224}
# INFO:tensorflow:Step 2400 per-step time 0.473s
# [07/22 21:15:13] tensorflow INFO: Step 2400 per-step time 0.473s
# INFO:tensorflow:{'Loss/classification_loss': 0.14687161,
#  'Loss/localization_loss': 0.09378817,
#  'Loss/regularization_loss': 0.15623532,
#  'Loss/total_loss': 0.3968951,
#  'learning_rate': 0.07933019}
# [07/22 21:15:13] tensorflow INFO: {'Loss/classification_loss': 0.14687161,
#  'Loss/localization_loss': 0.09378817,
#  'Loss/regularization_loss': 0.15623532,
#  'Loss/total_loss': 0.3968951,
#  'learning_rate': 0.07933019}
# INFO:tensorflow:Step 2500 per-step time 0.485s
# [07/22 21:16:01] tensorflow INFO: Step 2500 per-step time 0.485s
# INFO:tensorflow:{'Loss/classification_loss': 0.15969604,
#  'Loss/localization_loss': 0.08929017,
#  'Loss/regularization_loss': 0.15601683,
#  'Loss/total_loss': 0.40500304,
#  'learning_rate': 0.07923141}
# [07/22 21:16:01] tensorflow INFO: {'Loss/classification_loss': 0.15969604,
#  'Loss/localization_loss': 0.08929017,
#  'Loss/regularization_loss': 0.15601683,
#  'Loss/total_loss': 0.40500304,
#  'learning_rate': 0.07923141}
# INFO:tensorflow:Step 2600 per-step time 0.735s
# [07/22 21:16:49] tensorflow INFO: Step 2600 per-step time 0.735s
# INFO:tensorflow:{'Loss/classification_loss': 0.12785484,
#  'Loss/localization_loss': 0.088437185,
#  'Loss/regularization_loss': 0.155803,
#  'Loss/total_loss': 0.37209502,
#  'learning_rate': 0.0791259}
# [07/22 21:16:49] tensorflow INFO: {'Loss/classification_loss': 0.12785484,
#  'Loss/localization_loss': 0.088437185,
#  'Loss/regularization_loss': 0.155803,
#  'Loss/total_loss': 0.37209502,
#  'learning_rate': 0.0791259}
# INFO:tensorflow:Step 2700 per-step time 0.432s
# [07/22 21:17:38] tensorflow INFO: Step 2700 per-step time 0.432s
# INFO:tensorflow:{'Loss/classification_loss': 0.110364854,
#  'Loss/localization_loss': 0.056723814,
#  'Loss/regularization_loss': 0.15548904,
#  'Loss/total_loss': 0.32257771,
#  'learning_rate': 0.07901369}
# [07/22 21:17:38] tensorflow INFO: {'Loss/classification_loss': 0.110364854,
#  'Loss/localization_loss': 0.056723814,
#  'Loss/regularization_loss': 0.15548904,
#  'Loss/total_loss': 0.32257771,
#  'learning_rate': 0.07901369}
# INFO:tensorflow:Step 2800 per-step time 0.445s
# [07/22 21:18:25] tensorflow INFO: Step 2800 per-step time 0.445s
# INFO:tensorflow:{'Loss/classification_loss': 0.11709543,
#  'Loss/localization_loss': 0.059187792,
#  'Loss/regularization_loss': 0.15514937,
#  'Loss/total_loss': 0.33143258,
#  'learning_rate': 0.078894794}
# [07/22 21:18:25] tensorflow INFO: {'Loss/classification_loss': 0.11709543,
#  'Loss/localization_loss': 0.059187792,
#  'Loss/regularization_loss': 0.15514937,
#  'Loss/total_loss': 0.33143258,
#  'learning_rate': 0.078894794}
# INFO:tensorflow:Step 2900 per-step time 0.514s
# [07/22 21:19:13] tensorflow INFO: Step 2900 per-step time 0.514s
# INFO:tensorflow:{'Loss/classification_loss': 0.14169987,
#  'Loss/localization_loss': 0.08166202,
#  'Loss/regularization_loss': 0.15479578,
#  'Loss/total_loss': 0.37815768,
#  'learning_rate': 0.07876924}
# [07/22 21:19:13] tensorflow INFO: {'Loss/classification_loss': 0.14169987,
#  'Loss/localization_loss': 0.08166202,
#  'Loss/regularization_loss': 0.15479578,
#  'Loss/total_loss': 0.37815768,
#  'learning_rate': 0.07876924}
# INFO:tensorflow:Step 3000 per-step time 0.472s
# [07/22 21:19:59] tensorflow INFO: Step 3000 per-step time 0.472s
# INFO:tensorflow:{'Loss/classification_loss': 0.09025732,
#  'Loss/localization_loss': 0.05316052,
#  'Loss/regularization_loss': 0.15453278,
#  'Loss/total_loss': 0.29795063,
#  'learning_rate': 0.07863703}
# [07/22 21:19:59] tensorflow INFO: {'Loss/classification_loss': 0.09025732,
#  'Loss/localization_loss': 0.05316052,
#  'Loss/regularization_loss': 0.15453278,
#  'Loss/total_loss': 0.29795063,
#  'learning_rate': 0.07863703}
# INFO:tensorflow:Step 3100 per-step time 0.531s
# [07/22 21:20:49] tensorflow INFO: Step 3100 per-step time 0.531s
# INFO:tensorflow:{'Loss/classification_loss': 0.17455436,
#  'Loss/localization_loss': 0.12400662,
#  'Loss/regularization_loss': 0.1541792,
#  'Loss/total_loss': 0.4527402,
#  'learning_rate': 0.07849821}
# [07/22 21:20:49] tensorflow INFO: {'Loss/classification_loss': 0.17455436,
#  'Loss/localization_loss': 0.12400662,
#  'Loss/regularization_loss': 0.1541792,
#  'Loss/total_loss': 0.4527402,
#  'learning_rate': 0.07849821}
# INFO:tensorflow:Step 3200 per-step time 0.460s
# [07/22 21:21:37] tensorflow INFO: Step 3200 per-step time 0.460s
# INFO:tensorflow:{'Loss/classification_loss': 0.12088198,
#  'Loss/localization_loss': 0.053389903,
#  'Loss/regularization_loss': 0.1538181,
#  'Loss/total_loss': 0.32808998,
#  'learning_rate': 0.07835279}
# [07/22 21:21:37] tensorflow INFO: {'Loss/classification_loss': 0.12088198,
#  'Loss/localization_loss': 0.053389903,
#  'Loss/regularization_loss': 0.1538181,
#  'Loss/total_loss': 0.32808998,
#  'learning_rate': 0.07835279}
# INFO:tensorflow:Step 3300 per-step time 0.472s
# [07/22 21:22:25] tensorflow INFO: Step 3300 per-step time 0.472s
# INFO:tensorflow:{'Loss/classification_loss': 0.094088465,
#  'Loss/localization_loss': 0.053759705,
#  'Loss/regularization_loss': 0.15341558,
#  'Loss/total_loss': 0.30126375,
#  'learning_rate': 0.078200795}
# [07/22 21:22:25] tensorflow INFO: {'Loss/classification_loss': 0.094088465,
#  'Loss/localization_loss': 0.053759705,
#  'Loss/regularization_loss': 0.15341558,
#  'Loss/total_loss': 0.30126375,
#  'learning_rate': 0.078200795}
# INFO:tensorflow:Step 3400 per-step time 0.419s
# [07/22 21:23:12] tensorflow INFO: Step 3400 per-step time 0.419s
# INFO:tensorflow:{'Loss/classification_loss': 0.12015221,
#  'Loss/localization_loss': 0.08119629,
#  'Loss/regularization_loss': 0.15304814,
#  'Loss/total_loss': 0.35439664,
#  'learning_rate': 0.078042254}
# [07/22 21:23:12] tensorflow INFO: {'Loss/classification_loss': 0.12015221,
#  'Loss/localization_loss': 0.08119629,
#  'Loss/regularization_loss': 0.15304814,
#  'Loss/total_loss': 0.35439664,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 3500 per-step time 0.529s
# [07/22 21:24:01] tensorflow INFO: Step 3500 per-step time 0.529s
# INFO:tensorflow:{'Loss/classification_loss': 0.09150675,
#  'Loss/localization_loss': 0.03798908,
#  'Loss/regularization_loss': 0.15255086,
#  'Loss/total_loss': 0.28204668,
#  'learning_rate': 0.07787721}
# [07/22 21:24:01] tensorflow INFO: {'Loss/classification_loss': 0.09150675,
#  'Loss/localization_loss': 0.03798908,
#  'Loss/regularization_loss': 0.15255086,
#  'Loss/total_loss': 0.28204668,
#  'learning_rate': 0.07787721}
# INFO:tensorflow:Step 3600 per-step time 0.461s
# [07/22 21:24:48] tensorflow INFO: Step 3600 per-step time 0.461s
# INFO:tensorflow:{'Loss/classification_loss': 0.08429505,
#  'Loss/localization_loss': 0.0499916,
#  'Loss/regularization_loss': 0.1521582,
#  'Loss/total_loss': 0.28644484,
#  'learning_rate': 0.07770566}
# [07/22 21:24:48] tensorflow INFO: {'Loss/classification_loss': 0.08429505,
#  'Loss/localization_loss': 0.0499916,
#  'Loss/regularization_loss': 0.1521582,
#  'Loss/total_loss': 0.28644484,
#  'learning_rate': 0.07770566}
# INFO:tensorflow:Step 3700 per-step time 0.559s
# [07/22 21:25:36] tensorflow INFO: Step 3700 per-step time 0.559s
# INFO:tensorflow:{'Loss/classification_loss': 0.089598745,
#  'Loss/localization_loss': 0.06267015,
#  'Loss/regularization_loss': 0.15179186,
#  'Loss/total_loss': 0.30406076,
#  'learning_rate': 0.07752766}
# [07/22 21:25:36] tensorflow INFO: {'Loss/classification_loss': 0.089598745,
#  'Loss/localization_loss': 0.06267015,
#  'Loss/regularization_loss': 0.15179186,
#  'Loss/total_loss': 0.30406076,
#  'learning_rate': 0.07752766}
# INFO:tensorflow:Step 3800 per-step time 0.466s
# [07/22 21:26:24] tensorflow INFO: Step 3800 per-step time 0.466s
# INFO:tensorflow:{'Loss/classification_loss': 0.09181735,
#  'Loss/localization_loss': 0.04389213,
#  'Loss/regularization_loss': 0.15130071,
#  'Loss/total_loss': 0.2870102,
#  'learning_rate': 0.07734321}
# [07/22 21:26:24] tensorflow INFO: {'Loss/classification_loss': 0.09181735,
#  'Loss/localization_loss': 0.04389213,
#  'Loss/regularization_loss': 0.15130071,
#  'Loss/total_loss': 0.2870102,
#  'learning_rate': 0.07734321}
# INFO:tensorflow:Step 3900 per-step time 0.446s
# [07/22 21:27:12] tensorflow INFO: Step 3900 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.10864157,
#  'Loss/localization_loss': 0.04797631,
#  'Loss/regularization_loss': 0.15094179,
#  'Loss/total_loss': 0.30755967,
#  'learning_rate': 0.07715238}
# [07/22 21:27:12] tensorflow INFO: {'Loss/classification_loss': 0.10864157,
#  'Loss/localization_loss': 0.04797631,
#  'Loss/regularization_loss': 0.15094179,
#  'Loss/total_loss': 0.30755967,
#  'learning_rate': 0.07715238}
# INFO:tensorflow:Step 4000 per-step time 0.467s
# [07/22 21:28:00] tensorflow INFO: Step 4000 per-step time 0.467s
# INFO:tensorflow:{'Loss/classification_loss': 0.11184128,
#  'Loss/localization_loss': 0.06338586,
#  'Loss/regularization_loss': 0.1505041,
#  'Loss/total_loss': 0.32573122,
#  'learning_rate': 0.076955184}
# [07/22 21:28:00] tensorflow INFO: {'Loss/classification_loss': 0.11184128,
#  'Loss/localization_loss': 0.06338586,
#  'Loss/regularization_loss': 0.1505041,
#  'Loss/total_loss': 0.32573122,
#  'learning_rate': 0.076955184}
# INFO:tensorflow:Step 4100 per-step time 0.482s
# [07/22 21:28:48] tensorflow INFO: Step 4100 per-step time 0.482s
# INFO:tensorflow:{'Loss/classification_loss': 0.09946284,
#  'Loss/localization_loss': 0.045174602,
#  'Loss/regularization_loss': 0.15029168,
#  'Loss/total_loss': 0.29492912,
#  'learning_rate': 0.07675164}
# [07/22 21:28:48] tensorflow INFO: {'Loss/classification_loss': 0.09946284,
#  'Loss/localization_loss': 0.045174602,
#  'Loss/regularization_loss': 0.15029168,
#  'Loss/total_loss': 0.29492912,
#  'learning_rate': 0.07675164}
# INFO:tensorflow:Step 4200 per-step time 0.492s
# [07/22 21:29:37] tensorflow INFO: Step 4200 per-step time 0.492s
# INFO:tensorflow:{'Loss/classification_loss': 0.13992356,
#  'Loss/localization_loss': 0.06076964,
#  'Loss/regularization_loss': 0.14983565,
#  'Loss/total_loss': 0.35052884,
#  'learning_rate': 0.07654182}
# [07/22 21:29:37] tensorflow INFO: {'Loss/classification_loss': 0.13992356,
#  'Loss/localization_loss': 0.06076964,
#  'Loss/regularization_loss': 0.14983565,
#  'Loss/total_loss': 0.35052884,
#  'learning_rate': 0.07654182}
# INFO:tensorflow:Step 4300 per-step time 0.504s
# [07/22 21:30:26] tensorflow INFO: Step 4300 per-step time 0.504s
# INFO:tensorflow:{'Loss/classification_loss': 0.09870003,
#  'Loss/localization_loss': 0.06380289,
#  'Loss/regularization_loss': 0.14950047,
#  'Loss/total_loss': 0.31200337,
#  'learning_rate': 0.07632572}
# [07/22 21:30:26] tensorflow INFO: {'Loss/classification_loss': 0.09870003,
#  'Loss/localization_loss': 0.06380289,
#  'Loss/regularization_loss': 0.14950047,
#  'Loss/total_loss': 0.31200337,
#  'learning_rate': 0.07632572}
# INFO:tensorflow:Step 4400 per-step time 0.427s
# [07/22 21:31:14] tensorflow INFO: Step 4400 per-step time 0.427s
# INFO:tensorflow:{'Loss/classification_loss': 0.08944919,
#  'Loss/localization_loss': 0.049230564,
#  'Loss/regularization_loss': 0.14910267,
#  'Loss/total_loss': 0.28778243,
#  'learning_rate': 0.07610341}
# [07/22 21:31:14] tensorflow INFO: {'Loss/classification_loss': 0.08944919,
#  'Loss/localization_loss': 0.049230564,
#  'Loss/regularization_loss': 0.14910267,
#  'Loss/total_loss': 0.28778243,
#  'learning_rate': 0.07610341}
# INFO:tensorflow:Step 4500 per-step time 0.455s
# [07/22 21:32:04] tensorflow INFO: Step 4500 per-step time 0.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.08471131,
#  'Loss/localization_loss': 0.04985256,
#  'Loss/regularization_loss': 0.14857496,
#  'Loss/total_loss': 0.28313884,
#  'learning_rate': 0.07587491}
# [07/22 21:32:04] tensorflow INFO: {'Loss/classification_loss': 0.08471131,
#  'Loss/localization_loss': 0.04985256,
#  'Loss/regularization_loss': 0.14857496,
#  'Loss/total_loss': 0.28313884,
#  'learning_rate': 0.07587491}
# INFO:tensorflow:Step 4600 per-step time 0.453s
# [07/22 21:32:51] tensorflow INFO: Step 4600 per-step time 0.453s
# INFO:tensorflow:{'Loss/classification_loss': 0.09602782,
#  'Loss/localization_loss': 0.05930152,
#  'Loss/regularization_loss': 0.14816022,
#  'Loss/total_loss': 0.30348957,
#  'learning_rate': 0.07564025}
# [07/22 21:32:51] tensorflow INFO: {'Loss/classification_loss': 0.09602782,
#  'Loss/localization_loss': 0.05930152,
#  'Loss/regularization_loss': 0.14816022,
#  'Loss/total_loss': 0.30348957,
#  'learning_rate': 0.07564025}
# INFO:tensorflow:Step 4700 per-step time 0.509s
# [07/22 21:33:39] tensorflow INFO: Step 4700 per-step time 0.509s
# INFO:tensorflow:{'Loss/classification_loss': 0.09763654,
#  'Loss/localization_loss': 0.0549676,
#  'Loss/regularization_loss': 0.14767492,
#  'Loss/total_loss': 0.30027908,
#  'learning_rate': 0.0753995}
# [07/22 21:33:39] tensorflow INFO: {'Loss/classification_loss': 0.09763654,
#  'Loss/localization_loss': 0.0549676,
#  'Loss/regularization_loss': 0.14767492,
#  'Loss/total_loss': 0.30027908,
#  'learning_rate': 0.0753995}
# INFO:tensorflow:Step 4800 per-step time 0.521s
# [07/22 21:34:26] tensorflow INFO: Step 4800 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.1350881,
#  'Loss/localization_loss': 0.051772296,
#  'Loss/regularization_loss': 0.14725694,
#  'Loss/total_loss': 0.33411735,
#  'learning_rate': 0.07515268}
# [07/22 21:34:26] tensorflow INFO: {'Loss/classification_loss': 0.1350881,
#  'Loss/localization_loss': 0.051772296,
#  'Loss/regularization_loss': 0.14725694,
#  'Loss/total_loss': 0.33411735,
#  'learning_rate': 0.07515268}
# INFO:tensorflow:Step 4900 per-step time 0.475s
# [07/22 21:35:13] tensorflow INFO: Step 4900 per-step time 0.475s
# INFO:tensorflow:{'Loss/classification_loss': 0.09312871,
#  'Loss/localization_loss': 0.038995527,
#  'Loss/regularization_loss': 0.14684568,
#  'Loss/total_loss': 0.27896994,
#  'learning_rate': 0.07489984}
# [07/22 21:35:13] tensorflow INFO: {'Loss/classification_loss': 0.09312871,
#  'Loss/localization_loss': 0.038995527,
#  'Loss/regularization_loss': 0.14684568,
#  'Loss/total_loss': 0.27896994,
#  'learning_rate': 0.07489984}
# INFO:tensorflow:Step 5000 per-step time 0.446s
# [07/22 21:36:01] tensorflow INFO: Step 5000 per-step time 0.446s
# INFO:tensorflow:{'Loss/classification_loss': 0.100055575,
#  'Loss/localization_loss': 0.04767661,
#  'Loss/regularization_loss': 0.1464828,
#  'Loss/total_loss': 0.29421496,
#  'learning_rate': 0.07464102}
# [07/22 21:36:01] tensorflow INFO: {'Loss/classification_loss': 0.100055575,
#  'Loss/localization_loss': 0.04767661,
#  'Loss/regularization_loss': 0.1464828,
#  'Loss/total_loss': 0.29421496,
#  'learning_rate': 0.07464102}
# INFO:tensorflow:Step 5100 per-step time 0.493s
# [07/22 21:36:50] tensorflow INFO: Step 5100 per-step time 0.493s
# INFO:tensorflow:{'Loss/classification_loss': 0.08453596,
#  'Loss/localization_loss': 0.05017259,
#  'Loss/regularization_loss': 0.14608264,
#  'Loss/total_loss': 0.2807912,
#  'learning_rate': 0.074376255}
# [07/22 21:36:50] tensorflow INFO: {'Loss/classification_loss': 0.08453596,
#  'Loss/localization_loss': 0.05017259,
#  'Loss/regularization_loss': 0.14608264,
#  'Loss/total_loss': 0.2807912,
#  'learning_rate': 0.074376255}
# INFO:tensorflow:Step 5200 per-step time 0.417s
# [07/22 21:37:37] tensorflow INFO: Step 5200 per-step time 0.417s
# INFO:tensorflow:{'Loss/classification_loss': 0.11005556,
#  'Loss/localization_loss': 0.050055858,
#  'Loss/regularization_loss': 0.14566563,
#  'Loss/total_loss': 0.30577704,
#  'learning_rate': 0.074105605}
# [07/22 21:37:37] tensorflow INFO: {'Loss/classification_loss': 0.11005556,
#  'Loss/localization_loss': 0.050055858,
#  'Loss/regularization_loss': 0.14566563,
#  'Loss/total_loss': 0.30577704,
#  'learning_rate': 0.074105605}
# INFO:tensorflow:Step 5300 per-step time 0.455s
# [07/22 21:38:27] tensorflow INFO: Step 5300 per-step time 0.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.0708967,
#  'Loss/localization_loss': 0.028956635,
#  'Loss/regularization_loss': 0.14518867,
#  'Loss/total_loss': 0.24504201,
#  'learning_rate': 0.07382911}
# [07/22 21:38:27] tensorflow INFO: {'Loss/classification_loss': 0.0708967,
#  'Loss/localization_loss': 0.028956635,
#  'Loss/regularization_loss': 0.14518867,
#  'Loss/total_loss': 0.24504201,
#  'learning_rate': 0.07382911}
# INFO:tensorflow:Step 5400 per-step time 0.411s
# [07/22 21:39:15] tensorflow INFO: Step 5400 per-step time 0.411s
# INFO:tensorflow:{'Loss/classification_loss': 0.12638335,
#  'Loss/localization_loss': 0.100154266,
#  'Loss/regularization_loss': 0.1447297,
#  'Loss/total_loss': 0.37126732,
#  'learning_rate': 0.07354682}
# [07/22 21:39:15] tensorflow INFO: {'Loss/classification_loss': 0.12638335,
#  'Loss/localization_loss': 0.100154266,
#  'Loss/regularization_loss': 0.1447297,
#  'Loss/total_loss': 0.37126732,
#  'learning_rate': 0.07354682}
# INFO:tensorflow:Step 5500 per-step time 0.521s
# [07/22 21:40:03] tensorflow INFO: Step 5500 per-step time 0.521s
# INFO:tensorflow:{'Loss/classification_loss': 0.078328244,
#  'Loss/localization_loss': 0.045608986,
#  'Loss/regularization_loss': 0.14421983,
#  'Loss/total_loss': 0.26815706,
#  'learning_rate': 0.07325879}
# [07/22 21:40:03] tensorflow INFO: {'Loss/classification_loss': 0.078328244,
#  'Loss/localization_loss': 0.045608986,
#  'Loss/regularization_loss': 0.14421983,
#  'Loss/total_loss': 0.26815706,
#  'learning_rate': 0.07325879}
# INFO:tensorflow:Step 5600 per-step time 0.484s
# [07/22 21:40:51] tensorflow INFO: Step 5600 per-step time 0.484s
# INFO:tensorflow:{'Loss/classification_loss': 0.151429,
#  'Loss/localization_loss': 0.06215414,
#  'Loss/regularization_loss': 0.14368793,
#  'Loss/total_loss': 0.35727108,
#  'learning_rate': 0.07296505}
# [07/22 21:40:51] tensorflow INFO: {'Loss/classification_loss': 0.151429,
#  'Loss/localization_loss': 0.06215414,
#  'Loss/regularization_loss': 0.14368793,
#  'Loss/total_loss': 0.35727108,
#  'learning_rate': 0.07296505}
# INFO:tensorflow:Step 5700 per-step time 0.520s
# [07/22 21:41:40] tensorflow INFO: Step 5700 per-step time 0.520s
# INFO:tensorflow:{'Loss/classification_loss': 0.05464384,
#  'Loss/localization_loss': 0.030563239,
#  'Loss/regularization_loss': 0.14326563,
#  'Loss/total_loss': 0.22847271,
#  'learning_rate': 0.07266566}
# [07/22 21:41:40] tensorflow INFO: {'Loss/classification_loss': 0.05464384,
#  'Loss/localization_loss': 0.030563239,
#  'Loss/regularization_loss': 0.14326563,
#  'Loss/total_loss': 0.22847271,
#  'learning_rate': 0.07266566}
# INFO:tensorflow:Step 5800 per-step time 0.450s
# [07/22 21:42:27] tensorflow INFO: Step 5800 per-step time 0.450s
# INFO:tensorflow:{'Loss/classification_loss': 0.06363945,
#  'Loss/localization_loss': 0.026045235,
#  'Loss/regularization_loss': 0.14277187,
#  'Loss/total_loss': 0.23245655,
#  'learning_rate': 0.07236068}
# [07/22 21:42:27] tensorflow INFO: {'Loss/classification_loss': 0.06363945,
#  'Loss/localization_loss': 0.026045235,
#  'Loss/regularization_loss': 0.14277187,
#  'Loss/total_loss': 0.23245655,
#  'learning_rate': 0.07236068}
# INFO:tensorflow:Step 5900 per-step time 0.627s
# [07/22 21:43:15] tensorflow INFO: Step 5900 per-step time 0.627s
# INFO:tensorflow:{'Loss/classification_loss': 0.07112456,
#  'Loss/localization_loss': 0.03774344,
#  'Loss/regularization_loss': 0.14219722,
#  'Loss/total_loss': 0.25106522,
#  'learning_rate': 0.07205015}
# [07/22 21:43:15] tensorflow INFO: {'Loss/classification_loss': 0.07112456,
#  'Loss/localization_loss': 0.03774344,
#  'Loss/regularization_loss': 0.14219722,
#  'Loss/total_loss': 0.25106522,
#  'learning_rate': 0.07205015}
# INFO:tensorflow:Step 6000 per-step time 0.516s
# [07/22 21:44:04] tensorflow INFO: Step 6000 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.10448374,
#  'Loss/localization_loss': 0.055052623,
#  'Loss/regularization_loss': 0.14165615,
#  'Loss/total_loss': 0.30119252,
#  'learning_rate': 0.07173413}
# [07/22 21:44:04] tensorflow INFO: {'Loss/classification_loss': 0.10448374,
#  'Loss/localization_loss': 0.055052623,
#  'Loss/regularization_loss': 0.14165615,
#  'Loss/total_loss': 0.30119252,
#  'learning_rate': 0.07173413}
# INFO:tensorflow:Step 6100 per-step time 0.443s
# [07/22 21:44:54] tensorflow INFO: Step 6100 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.10885955,
#  'Loss/localization_loss': 0.044814765,
#  'Loss/regularization_loss': 0.14154701,
#  'Loss/total_loss': 0.29522133,
#  'learning_rate': 0.071412675}
# [07/22 21:44:54] tensorflow INFO: {'Loss/classification_loss': 0.10885955,
#  'Loss/localization_loss': 0.044814765,
#  'Loss/regularization_loss': 0.14154701,
#  'Loss/total_loss': 0.29522133,
#  'learning_rate': 0.071412675}
# INFO:tensorflow:Step 6200 per-step time 0.422s
# [07/22 21:45:40] tensorflow INFO: Step 6200 per-step time 0.422s
# INFO:tensorflow:{'Loss/classification_loss': 0.064858034,
#  'Loss/localization_loss': 0.03425411,
#  'Loss/regularization_loss': 0.14106739,
#  'Loss/total_loss': 0.24017954,
#  'learning_rate': 0.07108584}
# [07/22 21:45:40] tensorflow INFO: {'Loss/classification_loss': 0.064858034,
#  'Loss/localization_loss': 0.03425411,
#  'Loss/regularization_loss': 0.14106739,
#  'Loss/total_loss': 0.24017954,
#  'learning_rate': 0.07108584}
# INFO:tensorflow:Step 6300 per-step time 0.430s
# [07/22 21:46:28] tensorflow INFO: Step 6300 per-step time 0.430s
# INFO:tensorflow:{'Loss/classification_loss': 0.06611543,
#  'Loss/localization_loss': 0.025145413,
#  'Loss/regularization_loss': 0.14056762,
#  'Loss/total_loss': 0.23182845,
#  'learning_rate': 0.07075367}
# [07/22 21:46:28] tensorflow INFO: {'Loss/classification_loss': 0.06611543,
#  'Loss/localization_loss': 0.025145413,
#  'Loss/regularization_loss': 0.14056762,
#  'Loss/total_loss': 0.23182845,
#  'learning_rate': 0.07075367}
# INFO:tensorflow:Step 6400 per-step time 0.424s
# [07/22 21:47:14] tensorflow INFO: Step 6400 per-step time 0.424s
# INFO:tensorflow:{'Loss/classification_loss': 0.07668595,
#  'Loss/localization_loss': 0.033219345,
#  'Loss/regularization_loss': 0.14007632,
#  'Loss/total_loss': 0.24998161,
#  'learning_rate': 0.07041624}
# [07/22 21:47:14] tensorflow INFO: {'Loss/classification_loss': 0.07668595,
#  'Loss/localization_loss': 0.033219345,
#  'Loss/regularization_loss': 0.14007632,
#  'Loss/total_loss': 0.24998161,
#  'learning_rate': 0.07041624}
# INFO:tensorflow:Step 6500 per-step time 0.450s
# [07/22 21:48:01] tensorflow INFO: Step 6500 per-step time 0.450s
# INFO:tensorflow:{'Loss/classification_loss': 0.09582141,
#  'Loss/localization_loss': 0.037313163,
#  'Loss/regularization_loss': 0.13949426,
#  'Loss/total_loss': 0.27262884,
#  'learning_rate': 0.0700736}
# [07/22 21:48:01] tensorflow INFO: {'Loss/classification_loss': 0.09582141,
#  'Loss/localization_loss': 0.037313163,
#  'Loss/regularization_loss': 0.13949426,
#  'Loss/total_loss': 0.27262884,
#  'learning_rate': 0.0700736}
# INFO:tensorflow:Step 6600 per-step time 0.606s
# [07/22 21:48:50] tensorflow INFO: Step 6600 per-step time 0.606s
# INFO:tensorflow:{'Loss/classification_loss': 0.09847661,
#  'Loss/localization_loss': 0.0724124,
#  'Loss/regularization_loss': 0.13893117,
#  'Loss/total_loss': 0.30982018,
#  'learning_rate': 0.06972579}
# [07/22 21:48:50] tensorflow INFO: {'Loss/classification_loss': 0.09847661,
#  'Loss/localization_loss': 0.0724124,
#  'Loss/regularization_loss': 0.13893117,
#  'Loss/total_loss': 0.30982018,
#  'learning_rate': 0.06972579}
# INFO:tensorflow:Step 6700 per-step time 0.481s
# [07/22 21:49:37] tensorflow INFO: Step 6700 per-step time 0.481s
# INFO:tensorflow:{'Loss/classification_loss': 0.058902092,
#  'Loss/localization_loss': 0.019613393,
#  'Loss/regularization_loss': 0.13848406,
#  'Loss/total_loss': 0.21699955,
#  'learning_rate': 0.0693729}
# [07/22 21:49:37] tensorflow INFO: {'Loss/classification_loss': 0.058902092,
#  'Loss/localization_loss': 0.019613393,
#  'Loss/regularization_loss': 0.13848406,
#  'Loss/total_loss': 0.21699955,
#  'learning_rate': 0.0693729}
# INFO:tensorflow:Step 6800 per-step time 0.455s
# [07/22 21:50:25] tensorflow INFO: Step 6800 per-step time 0.455s
# INFO:tensorflow:{'Loss/classification_loss': 0.0675522,
#  'Loss/localization_loss': 0.024097336,
#  'Loss/regularization_loss': 0.13800378,
#  'Loss/total_loss': 0.22965333,
#  'learning_rate': 0.069014974}
# [07/22 21:50:25] tensorflow INFO: {'Loss/classification_loss': 0.0675522,
#  'Loss/localization_loss': 0.024097336,
#  'Loss/regularization_loss': 0.13800378,
#  'Loss/total_loss': 0.22965333,
#  'learning_rate': 0.069014974}
# INFO:tensorflow:Step 6900 per-step time 0.459s
# [07/22 21:51:13] tensorflow INFO: Step 6900 per-step time 0.459s
# INFO:tensorflow:{'Loss/classification_loss': 0.08449923,
#  'Loss/localization_loss': 0.028093146,
#  'Loss/regularization_loss': 0.1377044,
#  'Loss/total_loss': 0.25029677,
#  'learning_rate': 0.06865208}
# [07/22 21:51:13] tensorflow INFO: {'Loss/classification_loss': 0.08449923,
#  'Loss/localization_loss': 0.028093146,
#  'Loss/regularization_loss': 0.1377044,
#  'Loss/total_loss': 0.25029677,
#  'learning_rate': 0.06865208}
# INFO:tensorflow:Step 7000 per-step time 0.408s
# [07/22 21:52:02] tensorflow INFO: Step 7000 per-step time 0.408s
# INFO:tensorflow:{'Loss/classification_loss': 0.07595691,
#  'Loss/localization_loss': 0.0372663,
#  'Loss/regularization_loss': 0.13729697,
#  'Loss/total_loss': 0.25052017,
#  'learning_rate': 0.06828427}
# [07/22 21:52:02] tensorflow INFO: {'Loss/classification_loss': 0.07595691,
#  'Loss/localization_loss': 0.0372663,
#  'Loss/regularization_loss': 0.13729697,
#  'Loss/total_loss': 0.25052017,
#  'learning_rate': 0.06828427}
# INFO:tensorflow:Step 7100 per-step time 0.473s
# [07/22 21:52:51] tensorflow INFO: Step 7100 per-step time 0.473s
# INFO:tensorflow:{'Loss/classification_loss': 0.1401365,
#  'Loss/localization_loss': 0.08483968,
#  'Loss/regularization_loss': 0.13688414,
#  'Loss/total_loss': 0.36186033,
#  'learning_rate': 0.06791162}
# [07/22 21:52:51] tensorflow INFO: {'Loss/classification_loss': 0.1401365,
#  'Loss/localization_loss': 0.08483968,
#  'Loss/regularization_loss': 0.13688414,
#  'Loss/total_loss': 0.36186033,
#  'learning_rate': 0.06791162}
# INFO:tensorflow:Step 7200 per-step time 0.482s
# [07/22 21:53:38] tensorflow INFO: Step 7200 per-step time 0.482s
# INFO:tensorflow:{'Loss/classification_loss': 0.05126542,
#  'Loss/localization_loss': 0.026162963,
#  'Loss/regularization_loss': 0.13645639,
#  'Loss/total_loss': 0.21388477,
#  'learning_rate': 0.06753418}
# [07/22 21:53:38] tensorflow INFO: {'Loss/classification_loss': 0.05126542,
#  'Loss/localization_loss': 0.026162963,
#  'Loss/regularization_loss': 0.13645639,
#  'Loss/total_loss': 0.21388477,
#  'learning_rate': 0.06753418}
# INFO:tensorflow:Step 7300 per-step time 0.462s
# [07/22 21:54:27] tensorflow INFO: Step 7300 per-step time 0.462s
# INFO:tensorflow:{'Loss/classification_loss': 0.070496395,
#  'Loss/localization_loss': 0.03214828,
#  'Loss/regularization_loss': 0.13593978,
#  'Loss/total_loss': 0.23858446,
#  'learning_rate': 0.06715202}
# [07/22 21:54:27] tensorflow INFO: {'Loss/classification_loss': 0.070496395,
#  'Loss/localization_loss': 0.03214828,
#  'Loss/regularization_loss': 0.13593978,
#  'Loss/total_loss': 0.23858446,
#  'learning_rate': 0.06715202}
# INFO:tensorflow:Step 7400 per-step time 0.664s
# [07/22 21:55:16] tensorflow INFO: Step 7400 per-step time 0.664s
# INFO:tensorflow:{'Loss/classification_loss': 0.06553987,
#  'Loss/localization_loss': 0.026655305,
#  'Loss/regularization_loss': 0.13541405,
#  'Loss/total_loss': 0.22760922,
#  'learning_rate': 0.06676522}
# [07/22 21:55:16] tensorflow INFO: {'Loss/classification_loss': 0.06553987,
#  'Loss/localization_loss': 0.026655305,
#  'Loss/regularization_loss': 0.13541405,
#  'Loss/total_loss': 0.22760922,
#  'learning_rate': 0.06676522}
# INFO:tensorflow:Step 7500 per-step time 0.457s
# [07/22 21:56:03] tensorflow INFO: Step 7500 per-step time 0.457s
# INFO:tensorflow:{'Loss/classification_loss': 0.09047261,
#  'Loss/localization_loss': 0.040125284,
#  'Loss/regularization_loss': 0.13496491,
#  'Loss/total_loss': 0.2655628,
#  'learning_rate': 0.066373825}
# [07/22 21:56:03] tensorflow INFO: {'Loss/classification_loss': 0.09047261,
#  'Loss/localization_loss': 0.040125284,
#  'Loss/regularization_loss': 0.13496491,
#  'Loss/total_loss': 0.2655628,
#  'learning_rate': 0.066373825}
# INFO:tensorflow:Step 7600 per-step time 0.451s
# [07/22 21:56:51] tensorflow INFO: Step 7600 per-step time 0.451s
# INFO:tensorflow:{'Loss/classification_loss': 0.0739248,
#  'Loss/localization_loss': 0.042054806,
#  'Loss/regularization_loss': 0.13464881,
#  'Loss/total_loss': 0.2506284,
#  'learning_rate': 0.06597792}
# [07/22 21:56:51] tensorflow INFO: {'Loss/classification_loss': 0.0739248,
#  'Loss/localization_loss': 0.042054806,
#  'Loss/regularization_loss': 0.13464881,
#  'Loss/total_loss': 0.2506284,
#  'learning_rate': 0.06597792}
# INFO:tensorflow:Step 7700 per-step time 0.597s
# [07/22 21:57:39] tensorflow INFO: Step 7700 per-step time 0.597s
# INFO:tensorflow:{'Loss/classification_loss': 0.067846306,
#  'Loss/localization_loss': 0.023946993,
#  'Loss/regularization_loss': 0.13421492,
#  'Loss/total_loss': 0.22600822,
#  'learning_rate': 0.06557756}
# [07/22 21:57:39] tensorflow INFO: {'Loss/classification_loss': 0.067846306,
#  'Loss/localization_loss': 0.023946993,
#  'Loss/regularization_loss': 0.13421492,
#  'Loss/total_loss': 0.22600822,
#  'learning_rate': 0.06557756}
# INFO:tensorflow:Step 7800 per-step time 0.512s
# [07/22 21:58:27] tensorflow INFO: Step 7800 per-step time 0.512s
# INFO:tensorflow:{'Loss/classification_loss': 0.07593475,
#  'Loss/localization_loss': 0.038638696,
#  'Loss/regularization_loss': 0.13371603,
#  'Loss/total_loss': 0.24828948,
#  'learning_rate': 0.065172814}
# [07/22 21:58:27] tensorflow INFO: {'Loss/classification_loss': 0.07593475,
#  'Loss/localization_loss': 0.038638696,
#  'Loss/regularization_loss': 0.13371603,
#  'Loss/total_loss': 0.24828948,
#  'learning_rate': 0.065172814}
# INFO:tensorflow:Step 7900 per-step time 0.436s
# [07/22 21:59:14] tensorflow INFO: Step 7900 per-step time 0.436s
# INFO:tensorflow:{'Loss/classification_loss': 0.07013868,
#  'Loss/localization_loss': 0.023463102,
#  'Loss/regularization_loss': 0.13323002,
#  'Loss/total_loss': 0.2268318,
#  'learning_rate': 0.064763755}
# [07/22 21:59:14] tensorflow INFO: {'Loss/classification_loss': 0.07013868,
#  'Loss/localization_loss': 0.023463102,
#  'Loss/regularization_loss': 0.13323002,
#  'Loss/total_loss': 0.2268318,
#  'learning_rate': 0.064763755}
# INFO:tensorflow:Step 8000 per-step time 0.527s
# [07/22 22:00:02] tensorflow INFO: Step 8000 per-step time 0.527s
# INFO:tensorflow:{'Loss/classification_loss': 0.06521572,
#  'Loss/localization_loss': 0.027758028,
#  'Loss/regularization_loss': 0.13283683,
#  'Loss/total_loss': 0.22581059,
#  'learning_rate': 0.064350456}
# [07/22 22:00:02] tensorflow INFO: {'Loss/classification_loss': 0.06521572,
#  'Loss/localization_loss': 0.027758028,
# ...
# INFO:tensorflow:Step 9100 per-step time 0.527s
# [07/22 22:08:47] tensorflow INFO: Step 9100 per-step time 0.527s
# INFO:tensorflow:{'Loss/classification_loss': 0.054057535,
#  'Loss/localization_loss': 0.024457619,
#  'Loss/regularization_loss': 0.12832512,
#  'Loss/total_loss': 0.20684028,
#  'learning_rate': 0.059544846}
# [07/22 22:08:47] tensorflow INFO: {'Loss/classification_loss': 0.054057535,
#  'Loss/localization_loss': 0.024457619,
#  'Loss/regularization_loss': 0.12832512,
#  'Loss/total_loss': 0.20684028,
#  'learning_rate': 0.059544846}
# INFO:tensorflow:Step 9200 per-step time 0.541s
# [07/22 22:09:33] tensorflow INFO: Step 9200 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.08923415,
#  'Loss/localization_loss': 0.027924325,
#  'Loss/regularization_loss': 0.12796584,
#  'Loss/total_loss': 0.24512431,
#  'learning_rate': 0.05908635}
# [07/22 22:09:33] tensorflow INFO: {'Loss/classification_loss': 0.08923415,
#  'Loss/localization_loss': 0.027924325,
#  'Loss/regularization_loss': 0.12796584,
#  'Loss/total_loss': 0.24512431,
#  'learning_rate': 0.05908635}
# INFO:tensorflow:Step 9300 per-step time 0.431s
# [07/22 22:10:20] tensorflow INFO: Step 9300 per-step time 0.431s
# INFO:tensorflow:{'Loss/classification_loss': 0.0774837,
#  'Loss/localization_loss': 0.029112559,
#  'Loss/regularization_loss': 0.127687,
#  'Loss/total_loss': 0.23428327,
#  'learning_rate': 0.05862458}
# [07/22 22:10:20] tensorflow INFO: {'Loss/classification_loss': 0.0774837,
#  'Loss/localization_loss': 0.029112559,
#  'Loss/regularization_loss': 0.127687,
#  'Loss/total_loss': 0.23428327,
#  'learning_rate': 0.05862458}
# INFO:tensorflow:Step 9400 per-step time 0.557s
# [07/22 22:11:09] tensorflow INFO: Step 9400 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.07891771,
#  'Loss/localization_loss': 0.035565484,
#  'Loss/regularization_loss': 0.12722676,
#  'Loss/total_loss': 0.24170995,
#  'learning_rate': 0.058159623}
# [07/22 22:11:09] tensorflow INFO: {'Loss/classification_loss': 0.07891771,
#  'Loss/localization_loss': 0.035565484,
#  'Loss/regularization_loss': 0.12722676,
#  'Loss/total_loss': 0.24170995,
#  'learning_rate': 0.058159623}
# INFO:tensorflow:Step 9500 per-step time 0.440s
# [07/22 22:11:56] tensorflow INFO: Step 9500 per-step time 0.440s
# INFO:tensorflow:{'Loss/classification_loss': 0.07602127,
#  'Loss/localization_loss': 0.029490905,
#  'Loss/regularization_loss': 0.12675063,
#  'Loss/total_loss': 0.2322628,
#  'learning_rate': 0.057691544}
# [07/22 22:11:56] tensorflow INFO: {'Loss/classification_loss': 0.07602127,
#  'Loss/localization_loss': 0.029490905,
#  'Loss/regularization_loss': 0.12675063,
#  'Loss/total_loss': 0.2322628,
#  'learning_rate': 0.057691544}
# INFO:tensorflow:Step 9600 per-step time 0.538s
# [07/22 22:12:43] tensorflow INFO: Step 9600 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.061725866,
#  'Loss/localization_loss': 0.026796425,
#  'Loss/regularization_loss': 0.12629844,
#  'Loss/total_loss': 0.21482074,
#  'learning_rate': 0.05722044}
# [07/22 22:12:43] tensorflow INFO: {'Loss/classification_loss': 0.061725866,
#  'Loss/localization_loss': 0.026796425,
#  'Loss/regularization_loss': 0.12629844,
#  'Loss/total_loss': 0.21482074,
#  'learning_rate': 0.05722044}
# INFO:tensorflow:Step 9700 per-step time 0.453s
# [07/22 22:13:32] tensorflow INFO: Step 9700 per-step time 0.453s
# INFO:tensorflow:{'Loss/classification_loss': 0.053971324,
#  'Loss/localization_loss': 0.01873951,
#  'Loss/regularization_loss': 0.12584585,
#  'Loss/total_loss': 0.19855669,
#  'learning_rate': 0.056746386}
# [07/22 22:13:32] tensorflow INFO: {'Loss/classification_loss': 0.053971324,
#  'Loss/localization_loss': 0.01873951,
#  'Loss/regularization_loss': 0.12584585,
#  'Loss/total_loss': 0.19855669,
#  'learning_rate': 0.056746386}
# INFO:tensorflow:Step 9800 per-step time 0.461s
# [07/22 22:14:19] tensorflow INFO: Step 9800 per-step time 0.461s
# INFO:tensorflow:{'Loss/classification_loss': 0.060323086,
#  'Loss/localization_loss': 0.026037373,
#  'Loss/regularization_loss': 0.12539165,
#  'Loss/total_loss': 0.2117521,
#  'learning_rate': 0.056269463}
# [07/22 22:14:19] tensorflow INFO: {'Loss/classification_loss': 0.060323086,
#  'Loss/localization_loss': 0.026037373,
#  'Loss/regularization_loss': 0.12539165,
#  'Loss/total_loss': 0.2117521,
#  'learning_rate': 0.056269463}
# INFO:tensorflow:Step 9900 per-step time 0.535s
# [07/22 22:15:06] tensorflow INFO: Step 9900 per-step time 0.535s
# INFO:tensorflow:{'Loss/classification_loss': 0.06362711,
#  'Loss/localization_loss': 0.039077096,
#  'Loss/regularization_loss': 0.12494302,
#  'Loss/total_loss': 0.22764722,
#  'learning_rate': 0.05578975}
# [07/22 22:15:06] tensorflow INFO: {'Loss/classification_loss': 0.06362711,
#  'Loss/localization_loss': 0.039077096,
#  'Loss/regularization_loss': 0.12494302,
#  'Loss/total_loss': 0.22764722,
#  'learning_rate': 0.05578975}
# INFO:tensorflow:Step 10000 per-step time 0.425s
# [07/22 22:15:53] tensorflow INFO: Step 10000 per-step time 0.425s
# INFO:tensorflow:{'Loss/classification_loss': 0.06547674,
#  'Loss/localization_loss': 0.024549112,
#  'Loss/regularization_loss': 0.124547996,
#  'Loss/total_loss': 0.21457385,
#  'learning_rate': 0.05530734}
# [07/22 22:15:53] tensorflow INFO: {'Loss/classification_loss': 0.06547674,
#  'Loss/localization_loss': 0.024549112,
#  'Loss/regularization_loss': 0.124547996,
#  'Loss/total_loss': 0.21457385,
#  'learning_rate': 0.05530734}
# INFO:tensorflow:Step 10100 per-step time 0.489s
# [07/22 22:16:42] tensorflow INFO: Step 10100 per-step time 0.489s
# INFO:tensorflow:{'Loss/classification_loss': 0.06255587,
#  'Loss/localization_loss': 0.027157344,
#  'Loss/regularization_loss': 0.124215804,
#  'Loss/total_loss': 0.21392903,
#  'learning_rate': 0.054822296}
# [07/22 22:16:42] tensorflow INFO: {'Loss/classification_loss': 0.06255587,
#  'Loss/localization_loss': 0.027157344,
#  'Loss/regularization_loss': 0.124215804,
#  'Loss/total_loss': 0.21392903,
#  'learning_rate': 0.054822296}
# INFO:tensorflow:Step 10200 per-step time 0.419s
# [07/22 22:17:29] tensorflow INFO: Step 10200 per-step time 0.419s
# INFO:tensorflow:{'Loss/classification_loss': 0.07133118,
#  'Loss/localization_loss': 0.037150495,
#  'Loss/regularization_loss': 0.12390852,
#  'Loss/total_loss': 0.2323902,
#  'learning_rate': 0.054334715}
# [07/22 22:17:29] tensorflow INFO: {'Loss/classification_loss': 0.07133118,
#  'Loss/localization_loss': 0.037150495,
#  'Loss/regularization_loss': 0.12390852,
#  'Loss/total_loss': 0.2323902,
#  'learning_rate': 0.054334715}
# INFO:tensorflow:Step 10300 per-step time 0.447s
# [07/22 22:18:16] tensorflow INFO: Step 10300 per-step time 0.447s
# INFO:tensorflow:{'Loss/classification_loss': 0.05891229,
#  'Loss/localization_loss': 0.024017036,
#  'Loss/regularization_loss': 0.12349245,
#  'Loss/total_loss': 0.20642178,
#  'learning_rate': 0.05384468}
# [07/22 22:18:16] tensorflow INFO: {'Loss/classification_loss': 0.05891229,
#  'Loss/localization_loss': 0.024017036,
#  'Loss/regularization_loss': 0.12349245,
#  'Loss/total_loss': 0.20642178,
#  'learning_rate': 0.05384468}
# INFO:tensorflow:Step 10400 per-step time 0.434s
# [07/22 22:19:03] tensorflow INFO: Step 10400 per-step time 0.434s
# INFO:tensorflow:{'Loss/classification_loss': 0.065574996,
#  'Loss/localization_loss': 0.030905446,
#  'Loss/regularization_loss': 0.123070225,
#  'Loss/total_loss': 0.21955067,
#  'learning_rate': 0.05335227}
# [07/22 22:19:03] tensorflow INFO: {'Loss/classification_loss': 0.065574996,
#  'Loss/localization_loss': 0.030905446,
#  'Loss/regularization_loss': 0.123070225,
#  'Loss/total_loss': 0.21955067,
#  'learning_rate': 0.05335227}
# INFO:tensorflow:Step 10500 per-step time 0.537s
# [07/22 22:19:51] tensorflow INFO: Step 10500 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.10298443,
#  'Loss/localization_loss': 0.050305128,
#  'Loss/regularization_loss': 0.12277118,
#  'Loss/total_loss': 0.27606073,
#  'learning_rate': 0.052857578}
# [07/22 22:19:51] tensorflow INFO: {'Loss/classification_loss': 0.10298443,
#  'Loss/localization_loss': 0.050305128,
#  'Loss/regularization_loss': 0.12277118,
#  'Loss/total_loss': 0.27606073,
#  'learning_rate': 0.052857578}
# INFO:tensorflow:Step 10600 per-step time 0.720s
# [07/22 22:20:39] tensorflow INFO: Step 10600 per-step time 0.720s
# INFO:tensorflow:{'Loss/classification_loss': 0.05238425,
#  'Loss/localization_loss': 0.014936848,
#  'Loss/regularization_loss': 0.12245711,
#  'Loss/total_loss': 0.18977821,
#  'learning_rate': 0.052360676}
# [07/22 22:20:39] tensorflow INFO: {'Loss/classification_loss': 0.05238425,
#  'Loss/localization_loss': 0.014936848,
#  'Loss/regularization_loss': 0.12245711,
#  'Loss/total_loss': 0.18977821,
#  'learning_rate': 0.052360676}
# INFO:tensorflow:Step 10700 per-step time 0.416s
# [07/22 22:21:26] tensorflow INFO: Step 10700 per-step time 0.416s
# INFO:tensorflow:{'Loss/classification_loss': 0.05587956,
#  'Loss/localization_loss': 0.020629084,
#  'Loss/regularization_loss': 0.12209298,
#  'Loss/total_loss': 0.19860162,
#  'learning_rate': 0.051861666}
# [07/22 22:21:26] tensorflow INFO: {'Loss/classification_loss': 0.05587956,
#  'Loss/localization_loss': 0.020629084,
#  'Loss/regularization_loss': 0.12209298,
#  'Loss/total_loss': 0.19860162,
#  'learning_rate': 0.051861666}
# INFO:tensorflow:Step 10800 per-step time 0.443s
# [07/22 22:22:13] tensorflow INFO: Step 10800 per-step time 0.443s
# INFO:tensorflow:{'Loss/classification_loss': 0.06952614,
#  'Loss/localization_loss': 0.029475696,
#  'Loss/regularization_loss': 0.12179395,
#  'Loss/total_loss': 0.22079578,
#  'learning_rate': 0.051360615}
# [07/22 22:22:13] tensorflow INFO: {'Loss/classification_loss': 0.06952614,
#  'Loss/localization_loss': 0.029475696,
#  'Loss/regularization_loss': 0.12179395,
#  'Loss/total_loss': 0.22079578,
#  'learning_rate': 0.051360615}
# INFO:tensorflow:Step 10900 per-step time 0.463s
# [07/22 22:23:01] tensorflow INFO: Step 10900 per-step time 0.463s
# INFO:tensorflow:{'Loss/classification_loss': 0.09432122,
#  'Loss/localization_loss': 0.0278519,
#  'Loss/regularization_loss': 0.121540606,
#  'Loss/total_loss': 0.24371374,
#  'learning_rate': 0.050857615}
# [07/22 22:23:01] tensorflow INFO: {'Loss/classification_loss': 0.09432122,
#  'Loss/localization_loss': 0.0278519,
#  'Loss/regularization_loss': 0.121540606,
#  'Loss/total_loss': 0.24371374,
#  'learning_rate': 0.050857615}
# INFO:tensorflow:Step 11000 per-step time 0.452s
# [07/22 22:23:48] tensorflow INFO: Step 11000 per-step time 0.452s
# INFO:tensorflow:{'Loss/classification_loss': 0.073619395,
#  'Loss/localization_loss': 0.03814803,
#  'Loss/regularization_loss': 0.12116191,
#  'Loss/total_loss': 0.23292933,
#  'learning_rate': 0.05035276}
# [07/22 22:23:48] tensorflow INFO: {'Loss/classification_loss': 0.073619395,
#  'Loss/localization_loss': 0.03814803,
#  'Loss/regularization_loss': 0.12116191,
#  'Loss/total_loss': 0.23292933,
#  'learning_rate': 0.05035276}
# INFO:tensorflow:Step 11100 per-step time 0.456s
# [07/22 22:24:38] tensorflow INFO: Step 11100 per-step time 0.456s
# INFO:tensorflow:{'Loss/classification_loss': 0.0649847,
#  'Loss/localization_loss': 0.026749168,
#  'Loss/regularization_loss': 0.12078807,
#  'Loss/total_loss': 0.21252194,
#  'learning_rate': 0.049846128}
# [07/22 22:24:38] tensorflow INFO: {'Loss/classification_loss': 0.0649847,
#  'Loss/localization_loss': 0.026749168,
#  'Loss/regularization_loss': 0.12078807,
#  'Loss/total_loss': 0.21252194,
#  'learning_rate': 0.049846128}
# INFO:tensorflow:Step 11200 per-step time 0.582s
# [07/22 22:25:25] tensorflow INFO: Step 11200 per-step time 0.582s
# INFO:tensorflow:{'Loss/classification_loss': 0.04868436,
#  'Loss/localization_loss': 0.020402426,
#  'Loss/regularization_loss': 0.12044247,
#  'Loss/total_loss': 0.18952926,
#  'learning_rate': 0.04933781}
# [07/22 22:25:25] tensorflow INFO: {'Loss/classification_loss': 0.04868436,
#  'Loss/localization_loss': 0.020402426,
#  'Loss/regularization_loss': 0.12044247,
#  'Loss/total_loss': 0.18952926,
#  'learning_rate': 0.04933781}
# INFO:tensorflow:Step 11300 per-step time 0.426s
# [07/22 22:26:11] tensorflow INFO: Step 11300 per-step time 0.426s
# INFO:tensorflow:{'Loss/classification_loss': 0.06899635,
#  'Loss/localization_loss': 0.03521659,
#  'Loss/regularization_loss': 0.12007944,
#  'Loss/total_loss': 0.22429238,
#  'learning_rate': 0.048827894}
# [07/22 22:26:11] tensorflow INFO: {'Loss/classification_loss': 0.06899635,
#  'Loss/localization_loss': 0.03521659,
#  'Loss/regularization_loss': 0.12007944,
#  'Loss/total_loss': 0.22429238,
#  'learning_rate': 0.048827894}
# INFO:tensorflow:Step 11400 per-step time 0.357s
# [07/22 22:26:59] tensorflow INFO: Step 11400 per-step time 0.357s
# INFO:tensorflow:{'Loss/classification_loss': 0.05804318,
#  'Loss/localization_loss': 0.020302124,
#  'Loss/regularization_loss': 0.11969903,
#  'Loss/total_loss': 0.19804433,
#  'learning_rate': 0.048316464}
# [07/22 22:26:59] tensorflow INFO: {'Loss/classification_loss': 0.05804318,
#  'Loss/localization_loss': 0.020302124,
#  'Loss/regularization_loss': 0.11969903,
#  'Loss/total_loss': 0.19804433,
#  'learning_rate': 0.048316464}
# INFO:tensorflow:Step 11500 per-step time 0.580s
# [07/22 22:27:47] tensorflow INFO: Step 11500 per-step time 0.580s
# INFO:tensorflow:{'Loss/classification_loss': 0.048045784,
#  'Loss/localization_loss': 0.022075433,
#  'Loss/regularization_loss': 0.11932242,
#  'Loss/total_loss': 0.18944363,
#  'learning_rate': 0.04780361}
# [07/22 22:27:47] tensorflow INFO: {'Loss/classification_loss': 0.048045784,
#  'Loss/localization_loss': 0.022075433,
#  'Loss/regularization_loss': 0.11932242,
#  'Loss/total_loss': 0.18944363,
#  'learning_rate': 0.04780361}
# INFO:tensorflow:Step 11600 per-step time 0.438s
# [07/22 22:28:33] tensorflow INFO: Step 11600 per-step time 0.438s
# INFO:tensorflow:{'Loss/classification_loss': 0.068696104,
#  'Loss/localization_loss': 0.03101645,
#  'Loss/regularization_loss': 0.11894528,
#  'Loss/total_loss': 0.21865782,
#  'learning_rate': 0.04728942}
# [07/22 22:28:33] tensorflow INFO: {'Loss/classification_loss': 0.068696104,
#  'Loss/localization_loss': 0.03101645,
#  'Loss/regularization_loss': 0.11894528,
#  'Loss/total_loss': 0.21865782,
#  'learning_rate': 0.04728942}
# INFO:tensorflow:Step 11700 per-step time 0.509s
# [07/22 22:29:21] tensorflow INFO: Step 11700 per-step time 0.509s
# INFO:tensorflow:{'Loss/classification_loss': 0.0546594,
#  'Loss/localization_loss': 0.033395458,
#  'Loss/regularization_loss': 0.118615866,
#  'Loss/total_loss': 0.20667073,
#  'learning_rate': 0.046773978}
# [07/22 22:29:21] tensorflow INFO: {'Loss/classification_loss': 0.0546594,
#  'Loss/localization_loss': 0.033395458,
#  'Loss/regularization_loss': 0.118615866,
#  'Loss/total_loss': 0.20667073,
#  'learning_rate': 0.046773978}
# INFO:tensorflow:Step 11800 per-step time 0.462s
# [07/22 22:30:09] tensorflow INFO: Step 11800 per-step time 0.462s
# INFO:tensorflow:{'Loss/classification_loss': 0.061472703,
#  'Loss/localization_loss': 0.030188572,
#  'Loss/regularization_loss': 0.11829018,
#  'Loss/total_loss': 0.20995146,
#  'learning_rate': 0.046257377}
# [07/22 22:30:09] tensorflow INFO: {'Loss/classification_loss': 0.061472703,
#  'Loss/localization_loss': 0.030188572,
#  'Loss/regularization_loss': 0.11829018,
#  'Loss/total_loss': 0.20995146,
#  'learning_rate': 0.046257377}
# INFO:tensorflow:Step 11900 per-step time 0.477s
# [07/22 22:30:57] tensorflow INFO: Step 11900 per-step time 0.477s
# INFO:tensorflow:{'Loss/classification_loss': 0.03531684,
#  'Loss/localization_loss': 0.016107557,
#  'Loss/regularization_loss': 0.11798242,
#  'Loss/total_loss': 0.16940682,
#  'learning_rate': 0.045739703}
# [07/22 22:30:57] tensorflow INFO: {'Loss/classification_loss': 0.03531684,
#  'Loss/localization_loss': 0.016107557,
#  'Loss/regularization_loss': 0.11798242,
#  'Loss/total_loss': 0.16940682,
#  'learning_rate': 0.045739703}
# INFO:tensorflow:Step 12000 per-step time 0.476s
# [07/22 22:31:45] tensorflow INFO: Step 12000 per-step time 0.476s
# INFO:tensorflow:{'Loss/classification_loss': 0.035433482,
#  'Loss/localization_loss': 0.016652264,
#  'Loss/regularization_loss': 0.11762982,
#  'Loss/total_loss': 0.16971557,
#  'learning_rate': 0.045221042}
# [07/22 22:31:45] tensorflow INFO: {'Loss/classification_loss': 0.035433482,
#  'Loss/localization_loss': 0.016652264,
#  'Loss/regularization_loss': 0.11762982,
#  'Loss/total_loss': 0.16971557,
#  'learning_rate': 0.045221042}

# %% [markdown]
# ### Run Evaluations Continuously

# %%
print("Starting evaluation...")
model_lib_v2.eval_continuously(
    pipeline_config_path=PIPELINE_CONFIG,
    model_dir=MODEL_DIR,
    checkpoint_dir=MODEL_DIR,
    eval_dir=EVAL_DIR,
    wait_interval=300,
    timeout=3600
)
# Out:
# Starting evaluation...
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# [07/15 03:31:49] tensorflow WARNING: Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting eval_dir: C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model\eval_logs
# [07/15 03:31:49] tensorflow INFO: Maybe overwriting eval_dir: C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model\eval_logs
# INFO:tensorflow:Ignoring config override key: eval_dir
# [07/15 03:31:49] tensorflow INFO: Ignoring config override key: eval_dir
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# [07/15 03:31:49] tensorflow INFO: Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# [07/15 03:31:49] tensorflow INFO: Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# [07/15 03:31:49] tensorflow INFO: Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# [07/15 03:31:49] tensorflow WARNING: Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:Reading unweighted datasets: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/val.record']
# [07/15 03:31:49] tensorflow INFO: Reading unweighted datasets: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/val.record']
# INFO:tensorflow:Reading record datasets for input file: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/val.record']
# [07/15 03:31:49] tensorflow INFO: Reading record datasets for input file: ['C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/val.record']
# INFO:tensorflow:Number of filenames to read: 1
# [07/15 03:31:49] tensorflow INFO: Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# [07/15 03:31:49] tensorflow WARNING: num_readers has been reduced to 1 to match input file shards.
# INFO:tensorflow:Waiting for new checkpoint at C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model
# [07/15 03:31:52] tensorflow INFO: Waiting for new checkpoint at C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model
# INFO:tensorflow:Found new checkpoint at C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model\ckpt-32
# [07/15 03:31:52] tensorflow INFO: Found new checkpoint at C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model\ckpt-32
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# [07/15 03:33:00] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# [07/15 03:33:00] tensorflow INFO: Finished eval step 0
# WARNING:tensorflow:From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
# [07/15 03:33:01] tensorflow WARNING: From C:\Users\ACER\.conda\envs\tfobjdetection\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
# INFO:tensorflow:Performing evaluation on 49 images.
# [07/15 03:34:14] tensorflow INFO: Performing evaluation on 49 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# [07/15 03:34:14] tensorflow INFO: Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# [07/15 03:34:14] tensorflow INFO: DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.42s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.050
# INFO:tensorflow:Eval metrics at step 30000
# [07/15 03:34:15] tensorflow INFO: Eval metrics at step 30000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.001263
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP: 0.001263
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.004118
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.004118
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000146
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000146
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.005354
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP (medium): 0.005354
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.001265
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Precision/mAP (large): 0.001265
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.007427
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@1: 0.007427
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.042160
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@10: 0.042160
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.048475
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@100: 0.048475
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.005208
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@100 (medium): 0.005208
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.049866
# [07/15 03:34:15] tensorflow INFO: 	+ DetectionBoxes_Recall/AR@100 (large): 0.049866
# INFO:tensorflow:	+ Loss/localization_loss: 0.694296
# [07/15 03:34:15] tensorflow INFO: 	+ Loss/localization_loss: 0.694296
# INFO:tensorflow:	+ Loss/classification_loss: 1.265191
# [07/15 03:34:15] tensorflow INFO: 	+ Loss/classification_loss: 1.265191
# INFO:tensorflow:	+ Loss/regularization_loss: 0.068610
# [07/15 03:34:15] tensorflow INFO: 	+ Loss/regularization_loss: 0.068610
# INFO:tensorflow:	+ Loss/total_loss: 2.028097
# [07/15 03:34:15] tensorflow INFO: 	+ Loss/total_loss: 2.028097
# INFO:tensorflow:Exiting evaluation at step 30000
# [07/15 03:34:16] tensorflow INFO: Exiting evaluation at step 30000

# %% [markdown]
# ### Export Trained Model

# %%
import subprocess

subprocess.run([
    "python",
    "C:/Users/ACER/Jupyter_Notebook_Workplace/models/research/object_detection/exporter_main_v2.py",
    "--input_type=image_tensor",
    "--pipeline_config_path=C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/pretrained/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config",
    "--trained_checkpoint_dir=C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_448_model",
    "--output_directory=C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/exported_model/ssd_mobilenet_v2_448_model_saved"
], check=True)

# %% [markdown]
# ### Load Exported Saved Model

# %%
EXPORT_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/exported_model/ssd_mobilenet_v2_448_model_saved/saved_model"
detect_fn = tf.saved_model.load(EXPORT_DIR)

print("Model loaded successfully.")
print("Signature keys:", list(detect_fn.signatures.keys()))

# Show detailed output structure
infer = detect_fn.signatures['serving_default']
print("\nOutput Signature:")
for key, val in infer.structured_outputs.items():
    print(f"{key}: {val}")
# Out:
# Loading saved model...

# %% [markdown]
# ### TensorBoard

# %%
# %load_ext tensorboard
# %tensorboard --logdir 'C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/training/ssd_mobilenet_v2_model'

# %% [markdown]
# ## Post-training TFLite FP16 Quantization

# %%
SAVED_MODEL_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/exported_model/ssd_mobilenet_v2_448_model_saved/saved_model"
TFLITE_MODEL_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/tflite_model"
TFLITE_MODEL_PATH = os.path.join(TFLITE_MODEL_DIR, "ssd_mobilenet_v2_448_model_fp16_flex.tflite")

os.makedirs(TFLITE_MODEL_DIR, exist_ok=True)

# Converter setup
converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL_DIR)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

# Enable fallback to TensorFlow ops (Flex ops)
converter.allow_custom_ops = True

# Convert
tflite_model = converter.convert()

# Save to file
with open(TFLITE_MODEL_PATH, 'wb') as f:
    f.write(tflite_model)

print(f"FP16 Flex TFLite model saved at: {TFLITE_MODEL_PATH}")

# %% [markdown]
# # Model Inference

# %%
import cv2
from object_detection.utils import label_map_util

# === Paths ===
VIDEO_PATH = "C:/Users/ACER/Downloads/WhatsApp Video 2025-07-05 at 18.49.47_6a8d5809.mp4"
MODEL_DIR = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/exported_model/ssd_mobilenet_v2_448_model_saved/saved_model"
LABEL_MAP_PATH = "C:/Users/ACER/Jupyter_Notebook_Workplace/Object-detection-dataset/label_map.pbtxt"

# === Load model and label map ===
print("Loading model...")
detect_fn = tf.saved_model.load(MODEL_DIR)
print("Model loaded.")

category_index = label_map_util.create_category_index_from_labelmap(LABEL_MAP_PATH, use_display_name=True)

# === Load video ===
cap = cv2.VideoCapture(VIDEO_PATH)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    input_tensor = tf.convert_to_tensor([cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)], dtype=tf.uint8)
    detections = detect_fn(input_tensor)

    num_detections = int(detections.pop('num_detections'))
    detections = {k: v[0, :num_detections].numpy() for k, v in detections.items()}
    boxes = detections['detection_boxes']
    scores = detections['detection_scores']
    classes = detections['detection_classes'].astype(np.int32)

    h, w, _ = frame.shape
    for i in range(num_detections):
        if scores[i] > 0.5:
            ymin, xmin, ymax, xmax = boxes[i]
            (left, right, top, bottom) = (xmin * w, xmax * w, ymin * h, ymax * h)
            cv2.rectangle(frame, (int(left), int(top)), (int(right), int(bottom)), (0, 255, 0), 2)

            class_id = classes[i]
            label = category_index.get(class_id, {'name': f'Class {class_id}'}).get('name', 'N/A')
            cv2.putText(frame, f'{label}: {int(scores[i]*100)}%', (int(left), int(top)-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (36,255,12), 2)

    cv2.imshow("Object Detection - SSD MobileNet V2", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Loading model...
